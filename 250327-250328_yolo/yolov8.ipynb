# %%
import gradio as gr
import numpy as np
import random
import platform
import cv2

from ultralytics import YOLO
from PIL import Image, ImageDraw, ImageFont

model = YOLO("yolov8n.pt")

def random_color():
    return (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

def get_font():
    font_size = 20
    if platform.system() == "Darwin":
        font = ImageFont.truetype("AppleGothic.ttf", size=font_size)
    elif platform.system() == "Windows":
        font = ImageFont.truetype("malgun.ttf", size=font_size)
    else:
        font = ImageFont.load_default(size=font_size)
    
    return font


def detect_objects(image):
    drawn_image = Image.fromarray(image.copy())
    draw = ImageDraw.Draw(drawn_image)

    response = model(image)

    for output in response:
        bounding_boxes_list = output.boxes.xyxy.cpu().numpy()
        confidence_list = output.boxes.conf.cpu().numpy()
        class_id_list = output.boxes.cls.cpu().numpy()
        labels_list = output.names

        for bounding_box, confidence, label_index in zip(bounding_boxes_list, confidence_list, class_id_list):
            x1, y1, x2, y2 = bounding_box
            ladel = labels_list[label_index]

            color = random_color()
            draw.rectangle((x1, y1, x2, y2), outline=color, width=3)
            draw.text((x1 + 5, y2 + 5), text="{} : {:.2f}%".format(ladel, confidence*100), fill=color, font=get_font())

    return drawn_image

with gr.Blocks() as demo:
    
    def stream_webcam(image):
        # detect function.
        drawn_image = detect_objects(image)
        return drawn_image
    
    webcam_input = gr.Image(label="실시간 화면", sources="webcam", width=480, height=270, mirror_webcam=False)
    output_image = gr.Image(label="검출 화면", type="pil")
    
    webcam_input.stream(stream_webcam, inputs=[webcam_input], outputs=[output_image])
    
demo.launch(server_port=8062)
# image = cv2.imread("C:/Users/jooeu/Desktop/git/ms-ai-school/250327-250328_yolo/test_image_2.png")
# detect_objects(image)
# Out:
# * Running on local URL:  http://127.0.0.1:8062
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:8062/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 0: 384x640 2 bowls, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 73.0ms
# Speed: 3.4ms preprocess, 73.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 69.6ms
# Speed: 2.4ms preprocess, 69.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 64.6ms
# Speed: 2.7ms preprocess, 64.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 69.0ms
# Speed: 1.8ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 60.4ms
# Speed: 2.2ms preprocess, 60.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 66.9ms
# Speed: 1.8ms preprocess, 66.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 70.6ms
# Speed: 2.8ms preprocess, 70.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 80.5ms
# Speed: 2.2ms preprocess, 80.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 68.8ms
# Speed: 1.5ms preprocess, 68.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 52.5ms
# Speed: 2.4ms preprocess, 52.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 80.5ms
# Speed: 2.8ms preprocess, 80.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 81.6ms
# Speed: 2.0ms preprocess, 81.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 60.8ms
# Speed: 1.5ms preprocess, 60.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 88.1ms
# Speed: 2.8ms preprocess, 88.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 109.6ms
# Speed: 3.3ms preprocess, 109.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 107.2ms
# Speed: 4.1ms preprocess, 107.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 74.2ms
# Speed: 1.9ms preprocess, 74.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 73.4ms
# Speed: 2.8ms preprocess, 73.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 65.5ms
# Speed: 2.1ms preprocess, 65.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 63.5ms
# Speed: 3.2ms preprocess, 63.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 78.6ms
# Speed: 1.8ms preprocess, 78.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 76.8ms
# Speed: 3.0ms preprocess, 76.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 bowls, 100.9ms
# Speed: 3.4ms preprocess, 100.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 69.4ms
# Speed: 1.5ms preprocess, 69.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 66.3ms
# Speed: 2.4ms preprocess, 66.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 65.4ms
# Speed: 1.7ms preprocess, 65.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 2 teddy bears, 122.5ms
# Speed: 3.3ms preprocess, 122.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 101.7ms
# Speed: 2.1ms preprocess, 101.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 73.3ms
# Speed: 3.0ms preprocess, 73.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 77.8ms
# Speed: 2.2ms preprocess, 77.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 67.4ms
# Speed: 3.6ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 104.7ms
# Speed: 6.2ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 54.5ms
# Speed: 2.2ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 83.4ms
# Speed: 2.9ms preprocess, 83.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 106.7ms
# Speed: 2.9ms preprocess, 106.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 98.9ms
# Speed: 1.7ms preprocess, 98.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 100.4ms
# Speed: 2.6ms preprocess, 100.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears, 108.5ms
# Speed: 5.6ms preprocess, 108.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 3 teddy bears,
9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 4 teddy bears, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 4 teddy bears, 57.3ms
# Speed: 2.3ms preprocess, 57.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 4 teddy bears, 66.8ms
# Speed: 2.3ms preprocess, 66.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 4 teddy bears, 77.2ms
# Speed: 2.7ms preprocess, 77.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 4 teddy bears, 92.6ms
# Speed: 1.6ms preprocess, 92.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 book, 4 teddy bears, 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 vase, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 64.5ms
# Speed: 2.3ms preprocess, 64.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 77.2ms
# Speed: 5.0ms preprocess, 77.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 66.3ms
# Speed: 1.7ms preprocess, 66.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 98.5ms
# Speed: 2.0ms preprocess, 98.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 51.1ms
# Speed: 1.7ms preprocess, 51.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 100.0ms
# Speed: 5.5ms preprocess, 100.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 84.7ms
# Speed: 3.2ms preprocess, 84.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 108.3ms
# Speed: 3.9ms preprocess, 108.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 64.7ms
# Speed: 2.7ms preprocess, 64.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 64.8ms
# Speed: 2.8ms preprocess, 64.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bottles, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 65.9ms
# Speed: 2.6ms preprocess, 65.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 63.7ms
# Speed: 2.4ms preprocess, 63.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 75.5ms
# Speed: 2.5ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 62.4ms
# Speed: 1.9ms preprocess, 62.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 71.2ms
# Speed: 1.8ms preprocess, 71.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 52.5ms
# Speed: 1.8ms preprocess, 52.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 71.3ms
# Speed: 3.0ms preprocess, 71.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 68.7ms
# Speed: 1.4ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 63.5ms
# Speed: 2.5ms preprocess, 63.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 82.7ms
# Speed: 2.5ms preprocess, 82.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 108.7ms
# Speed: 3.9ms preprocess, 108.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 90.8ms
# Speed: 2.6ms preprocess, 90.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 104.7ms
# Speed: 2.6ms preprocess, 104.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 76.7ms
# Speed: 2.6ms preprocess, 76.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 100.7ms
# Speed: 2.6ms preprocess, 100.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 64.9ms
# Speed: 2.7ms preprocess, 64.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 65.0ms
# Speed: 2.8ms preprocess, 65.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 69.5ms
# Speed: 4.1ms preprocess, 69.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 refrigerator, 70.1ms
# Speed: 3.4ms preprocess, 70.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 74.0ms
# Speed: 2.7ms preprocess, 74.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 67.7ms
# Speed: 3.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 63.6ms
# Speed: 1.4ms preprocess, 63.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 64.5ms
# Speed: 3.4ms preprocess, 64.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 65.4ms
# Speed: 2.7ms preprocess, 65.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 69.0ms
# Speed: 2.3ms preprocess, 69.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 120.9ms
# Speed: 3.6ms preprocess, 120.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 87.9ms
# Speed: 4.4ms preprocess, 87.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 68.4ms
# Speed: 2.2ms preprocess, 68.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 62.7ms
# Speed: 2.5ms preprocess, 62.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 44.5ms
# Speed: 2.2ms preprocess, 44.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 56.5ms
# Speed: 1.8ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 108.8ms
# Speed: 3.0ms preprocess, 108.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 81.6ms
# Speed: 2.6ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 61.5ms
# Speed: 1.6ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 107.2ms
# Speed: 2.7ms preprocess, 107.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 61.6ms
# Speed: 2.3ms preprocess, 61.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 73.9ms
# Speed: 1.6ms preprocess, 73.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 79.3ms
# Speed: 2.9ms preprocess, 79.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 98.5ms
# Speed: 2.5ms preprocess, 98.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 65.9ms
# Speed: 1.8ms preprocess, 65.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 109.4ms
# Speed: 3.7ms preprocess, 109.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 63.7ms
# Speed: 1.5ms preprocess, 63.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 58.2ms
# Speed: 2.3ms preprocess, 58.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 100.7ms
# Speed: 1.6ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 63.2ms
# Speed: 3.0ms preprocess, 63.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 87.9ms
# Speed: 5.7ms preprocess, 87.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 66.6ms
# Speed: 2.2ms preprocess, 66.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 62.0ms
# Speed: 1.7ms preprocess, 62.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 47.2ms
# Speed: 2.2ms preprocess, 47.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 88.5ms
# Speed: 6.2ms preprocess, 88.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 84.2ms
# Speed: 2.9ms preprocess, 84.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 91.8ms
# Speed: 2.7ms preprocess, 91.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bus, 1 book, 62.2ms
# Speed: 2.7ms preprocess, 62.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 61.7ms
# Speed: 2.6ms preprocess, 61.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bus, 1 book, 64.1ms
# Speed: 1.7ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
